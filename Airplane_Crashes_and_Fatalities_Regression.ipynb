# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
##from google.colab import files
#files.upload()

# %%
import pandas as pd

# %%
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv('airplane.csv')

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#    index        Date   Time                            Location  \
# 0      0  09/17/1908  17:18                 Fort Myer, Virginia
# 1      1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2      2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3      3  09/09/1913  18:30                  Over the North Sea
# 4      4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# ...

# %%
df.tail()
# Out:
#       index        Date   Time  \
# 5263   5263  05/20/2009  06:30
# 5264   5264  05/26/2009    NaN
# 5265   5265  06/01/2009  00:15
# 5266   5266  06/07/2009  08:30
# 5267   5267  06/08/2009    NaN
#
#                                                Location  \
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266       Near Port Hope Simpson, Newfoundland, Canada
# 5267                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# ...

# %%
df.sample(3)
# Out:
#       index        Date   Time                 Location            Operator  \
# 2555   2555  05/30/1972  06:24  Dallas/Ft. Worth, Texas     Delta Air Lines
# 2268   2268  11/25/1968    NaN        Savannakhet, Laos         Air America
# 3062   3062  06/26/1978    NaN       Off Bergen, Norway  Helikopter Service
#
#      Flight #                  Route                       Type Registration  \
# 2555     9570               Training  McDonnell Douglas DC-9-14       N3305L
# 2268      NaN                    NaN        Curtiss C-46D-20-CU       N1386N
# 3062      NaN  Bergen - Stratjford-A             Sikorsky S-61N       LN-OQS
#
#       cn/In  Aboard  Fatalities  Ground  \
# 2555  45700     4.0         4.0     0.0
# 2268  22265    28.0        26.0     0.0
# 3062    NaN    18.0        18.0     0.0
#
#                                                 Summary
# 2555  While practicing touch and go landing the airc...
# 2268                  Crashed shortly after taking off.
# ...

# %%
df.shape
# Out:
# (5268, 14)

# %%
df.describe()
# Out:
#             index       Aboard   Fatalities       Ground
# count  5268.00000  5246.000000  5256.000000  5246.000000
# mean   2633.50000    27.554518    20.068303     1.608845
# std    1520.88494    43.076711    33.199952    53.987827
# min       0.00000     0.000000     0.000000     0.000000
# 25%    1316.75000     5.000000     3.000000     0.000000
# 50%    2633.50000    13.000000     9.000000     0.000000
# 75%    3950.25000    30.000000    23.000000     0.000000
# max    5267.00000   644.000000   583.000000  2750.000000

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route',
#        'Type', 'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground',
#        'Summary'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# index              0
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
df.corr()
# Out:
#                index    Aboard  Fatalities    Ground
# index       1.000000  0.146481    0.097453  0.031080
# Aboard      0.146481  1.000000    0.757172  0.023241
# Fatalities  0.097453  0.757172    1.000000  0.035170
# Ground      0.031080  0.023241    0.035170  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         5268 non-null   int64
#  1   Date          5268 non-null   object
#  2   Time          3049 non-null   object
#  3   Location      5248 non-null   object
#  4   Operator      5250 non-null   object
#  5   Flight #      1069 non-null   object
#  6   Route         3562 non-null   object
#  7   Type          5241 non-null   object
#  8   Registration  4933 non-null   object
#  9   cn/In         4040 non-null   object
#  10  Aboard        5246 non-null   float64
#  11  Fatalities    5256 non-null   float64
#  12  Ground        5246 non-null   float64
#  13  Summary       4878 non-null   object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 576.3+ KB

# %%
df[['Fatalities']].value_counts()
# Out:
# Fatalities
# 2.0           528
# 3.0           458
# 1.0           409
# 4.0           328
# 5.0           260
#              ...
# 188.0           1
# 189.0           1
# 191.0           1
# 196.0           1
# 583.0           1
# Length: 191, dtype: int64

# %%
df.sort_values('Fatalities', ascending=False)
# Out:
#       index        Date   Time                                 Location  \
# 2963   2963  03/27/1977  17:07                 Tenerife, Canary Islands
# 3568   3568  08/12/1985  18:56    Mt. Osutaka, near Ueno Village, Japan
# 4455   4455  11/12/1996  18:40                 Near Charkhidadri, India
# 2726   2726  03/03/1974  11:41                Near Ermenonville, France
# 3562   3562  06/23/1985  07:15  AtlantiOcean, 110 miles West of Ireland
# ...     ...         ...    ...                                      ...
# 573     573  02/14/1942    NaN                                      NaN
# 593     593  10/01/1942    NaN                           Kunming, China
# 678     678  11/09/1944    NaN                          Seljord, Norway
# 768     768  03/18/1946    NaN    Between Chungking and Shanghai, China
# 4705   4705  03/22/2000    NaN                          Herreira, Spain
#
#                                         Operator   Flight #  \
# ...

# %% [markdown]
# ### Feature Engineering

# %%
df['Fatality Rate'] = df['Fatalities']/df['Aboard']

# %%
df
# Out:
#       index        Date   Time  \
# 0         0  09/17/1908  17:18
# 1         1  07/12/1912  06:30
# 2         2  08/06/1913    NaN
# 3         3  09/09/1913  18:30
# 4         4  10/17/1913  10:30
# ...     ...         ...    ...
# 5263   5263  05/20/2009  06:30
# 5264   5264  05/26/2009    NaN
# 5265   5265  06/01/2009  00:15
# 5266   5266  06/07/2009  08:30
# 5267   5267  06/08/2009    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# ...

# %%
df['Fatality Rate'] = (df['Fatalities']/df['Aboard'])*100

# %%
df
# Out:
#       index        Date   Time  \
# 0         0  09/17/1908  17:18
# 1         1  07/12/1912  06:30
# 2         2  08/06/1913    NaN
# 3         3  09/09/1913  18:30
# 4         4  10/17/1913  10:30
# ...     ...         ...    ...
# 5263   5263  05/20/2009  06:30
# 5264   5264  05/26/2009    NaN
# 5265   5265  06/01/2009  00:15
# 5266   5266  06/07/2009  08:30
# 5267   5267  06/08/2009    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          5268 non-null   int64
#  1   Date           5268 non-null   datetime64[ns]
#  2   Time           3049 non-null   object
#  3   Location       5248 non-null   object
#  4   Operator       5250 non-null   object
#  5   Flight #       1069 non-null   object
#  6   Route          3562 non-null   object
#  7   Type           5241 non-null   object
#  8   Registration   4933 non-null   object
#  9   cn/In          4040 non-null   object
#  10  Aboard         5246 non-null   float64
#  11  Fatalities     5256 non-null   float64
#  12  Ground         5246 non-null   float64
#  13  Summary        4878 non-null   object
#  14  Fatality Rate  5244 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(9)
# memory usage: 617.5+ KB

# %%
df['day'] = (df["Date"]).dt.day
df['month'] = (df["Date"]).dt.month
df['year'] = (df['Date']).dt.year

# %%
df
# Out:
#       index       Date   Time  \
# 0         0 1908-09-17  17:18
# 1         1 1912-07-12  06:30
# 2         2 1913-08-06    NaN
# 3         3 1913-09-09  18:30
# 4         4 1913-10-17  10:30
# ...     ...        ...    ...
# 5263   5263 2009-05-20  06:30
# 5264   5264 2009-05-26    NaN
# 5265   5265 2009-06-01  00:15
# 5266   5266 2009-06-07  08:30
# 5267   5267 2009-06-08    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# ...

# %%
df['month_name'] = df['Date'].dt.month_name()

# %%
df['month_name']
# Out:
# 0       September
# 1            July
# 2          August
# 3       September
# 4         October
#           ...
# 5263          May
# 5264          May
# 5265         June
# 5266         June
# 5267         June
# Name: month_name, Length: 5268, dtype: object

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(8,6))
plt.title('Monthly Incident')
sns.countplot(df['month_name'])
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(8,6))
plt.title('Daily Incident')
sns.countplot(df['day'])
plt.xticks(rotation=45);

# %%
df['day_name'] = df['Date'].dt.day_name()

# %%
df['day_name']
# Out:
# 0        Thursday
# 1          Friday
# 2       Wednesday
# 3         Tuesday
# 4          Friday
#           ...
# 5263    Wednesday
# 5264      Tuesday
# 5265       Monday
# 5266       Sunday
# 5267       Monday
# Name: day_name, Length: 5268, dtype: object

# %%
plt.figure(figsize=(8,6))
plt.title('Daily Incident')
sns.countplot(df['day_name'])
plt.xticks(rotation=45);

# %%
df['Survived'] = df['Aboard']-df['Fatalities']

# %%
df
# Out:
#       index       Date   Time  \
# 0         0 1908-09-17  17:18
# 1         1 1912-07-12  06:30
# 2         2 1913-08-06    NaN
# 3         3 1913-09-09  18:30
# 4         4 1913-10-17  10:30
# ...     ...        ...    ...
# 5263   5263 2009-05-20  06:30
# 5264   5264 2009-05-26    NaN
# 5265   5265 2009-06-01  00:15
# 5266   5266 2009-06-07  08:30
# 5267   5267 2009-06-08    NaN
#
#                                                Location  \
# 0                                   Fort Myer, Virginia
# 1                               AtlantiCity, New Jersey
# 2                    Victoria, British Columbia, Canada
# 3                                    Over the North Sea
# 4                            Near Johannisthal, Germany
# ...                                                 ...
# 5263                             Near Madiun, Indonesia
# 5264                  Near Isiro, DemocratiRepubliCongo
# 5265  AtlantiOcean, 570 miles northeast of Natal, Br...
# ...

# %%
plt.figure(figsize=(20, 15))
plt.title('Male vs Female Customers')
sns.countplot(df['Fatalities']);

# %%
sns.heatmap(df.corr(), annot=True, cmap='flag')

# %%
df.corr()
# Out:
#                   index    Aboard  Fatalities    Ground  Fatality Rate  \
# index          1.000000  0.146481    0.097453  0.031080      -0.061977
# Aboard         0.146481  1.000000    0.757172  0.023241      -0.227193
# Fatalities     0.097453  0.757172    1.000000  0.035170       0.186248
# Ground         0.031080  0.023241    0.035170  1.000000       0.008693
# Fatality Rate -0.061977 -0.227193    0.186248  0.008693       1.000000
# day           -0.002084  0.014114   -0.004081 -0.012044      -0.027806
# month         -0.011104  0.035400    0.029323  0.013277      -0.007929
# year           0.991628  0.156472    0.109586  0.029193      -0.064132
# Survived       0.108784  0.637063   -0.021140 -0.005907      -0.567472
#
#                     day     month      year  Survived
# index         -0.002084 -0.011104  0.991628  0.108784
# Aboard         0.014114  0.035400  0.156472  0.637063
# Fatalities    -0.004081  0.029323  0.109586 -0.021140
# ...

# %%
abs(df.corr()["Survived"]).sort_values(ascending=False)
# Out:
# Survived         1.000000
# Aboard           0.637063
# Fatality Rate    0.567472
# year             0.109766
# index            0.108784
# day              0.027081
# Fatalities       0.021140
# month            0.020207
# Ground           0.005907
# Name: Survived, dtype: float64

# %%
abs(df.corr()["Fatality Rate"]).sort_values(ascending=False)
# Out:
# Fatality Rate    1.000000
# Survived         0.567472
# Aboard           0.227193
# Fatalities       0.186248
# year             0.064132
# index            0.061977
# day              0.027806
# Ground           0.008693
# month            0.007929
# Name: Fatality Rate, dtype: float64

# %%
df.isnull().sum()
# Out:
# index               0
# Date                0
# Time             2219
# Location           20
# Operator           18
# Flight #         4199
# Route            1706
# Type               27
# Registration      335
# cn/In            1228
# Aboard             22
# Fatalities         12
# Ground             22
# Summary           390
# Fatality Rate      24
# day                 0
# month               0
# year                0
# month_name          0
# day_name            0
# Survived           22
# dtype: int64

# %%
a=df['Survived'].mean()

# %%
df['Survived']=df['Survived'].fillna(a)

# %%
df.isnull().sum()
# Out:
# index               0
# Date                0
# Time             2219
# Location           20
# Operator           18
# Flight #         4199
# Route            1706
# Type               27
# Registration      335
# cn/In            1228
# Aboard             22
# Fatalities         12
# Ground             22
# Summary           390
# Fatality Rate      24
# day                 0
# month               0
# year                0
# month_name          0
# day_name            0
# Survived            0
# dtype: int64

# %%
c=df['Aboard'].mean()

# %%
df['Aboard']=df['Aboard'].fillna(c)

# %%
df.isnull().sum()
# Out:
# index               0
# Date                0
# Time             2219
# Location           20
# Operator           18
# Flight #         4199
# Route            1706
# Type               27
# Registration      335
# cn/In            1228
# Aboard              0
# Fatalities         12
# Ground             22
# Summary           390
# Fatality Rate      24
# day                 0
# month               0
# year                0
# month_name          0
# day_name            0
# Survived            0
# dtype: int64

# %%
d=df['Fatality Rate'].mean()

# %%
d
# Out:
# 83.49315979825221

# %%
df['Fatality Rate']=df['Fatality Rate'].fillna(d)

# %%
df.isnull().sum()
# Out:
# index               0
# Date                0
# Time             2219
# Location           20
# Operator           18
# Flight #         4199
# Route            1706
# Type               27
# Registration      335
# cn/In            1228
# Aboard              0
# Fatalities         12
# Ground             22
# Summary           390
# Fatality Rate       0
# day                 0
# month               0
# year                0
# month_name          0
# day_name            0
# Survived            0
# dtype: int64

# %%
f=df['Fatalities'].mean()

# %%
df['Fatalities']=df['Fatalities'].fillna(f)

# %%
df.isnull().sum()
# Out:
# index               0
# Date                0
# Time             2219
# Location           20
# Operator           18
# Flight #         4199
# Route            1706
# Type               27
# Registration      335
# cn/In            1228
# Aboard              0
# Fatalities          0
# Ground             22
# Summary           390
# Fatality Rate       0
# day                 0
# month               0
# year                0
# month_name          0
# day_name            0
# Survived            0
# dtype: int64

# %%
df.drop(["Summary","Time","Date","Registration","Route","Flight #","cn/In"], axis=1, inplace=True)

# %% [markdown]
# ### Regression

# %%
# !pip install pycaret

# %%
from pycaret.regression import *

# %%
exp_name=setup(data=df,target="Fatalities")

# %%
best=compare_models()
# Out:
#                                     Model      MAE         MSE      RMSE  \
# lasso                    Lasso Regression   0.0887      0.6921    0.6459
# en                            Elastic Net   0.0878      0.6924    0.6467
# br                         Bayesian Ridge   0.1192      0.6942    0.6853
# par          Passive Aggressive Regressor   0.1038      0.6953    0.6462
# ridge                    Ridge Regression   0.1828      0.7393    0.7640
# huber                     Huber Regressor   0.0938      0.7464    0.6902
# lr                      Linear Regression   0.2139      1.2206    1.0603
# omp           Orthogonal Matching Pursuit   0.0753      1.3511    1.1235
# gbr           Gradient Boosting Regressor   0.9223     15.3626    3.2196
# rf                Random Forest Regressor   0.5418     25.4800    3.8760
# knn                 K Neighbors Regressor   1.5088     34.0068    4.8064
# dt                Decision Tree Regressor   0.8063     36.0961    4.9130
# ...
